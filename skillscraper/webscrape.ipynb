# %%
from bs4 import BeautifulSoup
from selenium import webdriver
#import qgrid
from urllib.request import Request, urlopen
import numpy as np
import pandas as pd

# %%
driver = webdriver.Firefox(executable_path='/Users/prasannsinghal/Desktop/geckodriver')
driver.get('https://www.allmusic.com/moods')

html = driver.page_source
soup = BeautifulSoup(html)
driver.quit()
#Set up connection and get page with all products

def extract_urls (page_link, start, end):
    textContent= []
    content = soup
    print(content)
    try:
        for i in range (start, end):
            z = content.find_all("a", href=True)
            textContent.append(z[i]['href'])
            print(z[i]['href'])
    except:
        print('******* INDEX EXCEEDED ********')
    return textContent

# %%
urls = extract_urls('https://www.allmusic.com/moods',0, 10000)
# Out:
# <html class="js"><!--<![endif]--><head>
# <meta charset="utf-8"/>
# <meta content="IE=Edge,chrome=1" http-equiv="X-UA-Compatible"/><script src="https://js-agent.newrelic.com/nr-1167.min.js"></script><script async="" referrerpolicy="unsafe-url" src="https://de.tynt.com/deb/v2?m=xch&amp;id=dXE5DyVPKr6yb7aKlId8sQ&amp;dn=RCIV&amp;cc=1&amp;r=" type="text/javascript"></script><script async="" referrerpolicy="unsafe-url" src="https://de.tynt.com/deb/v2?id=dXE5DyVPKr6yb7aKlId8sQ&amp;dn=RCIV&amp;cc=1&amp;r=" type="text/javascript"></script><script src="https://www.googletagservices.com/activeview/js/current/osd.js?cb=%2Fr20100101"></script><script src="https://securepubads.g.doubleclick.net/gpt/pubads_impl_rendering_2020032401.js?21065778"></script><script async="" src="https://rules.quantcount.com/rules-p-59TntzuqummDw.js"></script><script async="" src="//cdn.adsafeprotected.com/iasPET.1.js"></script><script async="" src="//p.cpx.to/p/12023/px.js" type="text/javascript"></script><script async="" src="//toolbar.complex.com/dist/ctoolbar.min.js" type="text/javascript"></script><script async="" src="https://sb.scorecardresearch.com/beacon.js"></script><script src="https://securepubads.g.doubleclick.net/tag/js/gpt.js"></script><script async="" src="https://ssl.google-analytics.com/ga.js"></script><script async="" src="//js-sec.indexww.com/ht/p/184233-278587170399516.js"></script><script async="" src="//c.amazon-adsystem.com/aax2/apstag.js"></script><script async="" src="https://quantcast.mgr.consensu.org/cmp.js" type="text/javascript"></script><script async="" src="https://secure.quantserve.com/quant.js" type="text/javascript"></script><script async="" src="//media.complex.com/common/cmnUNT.js" type="text/javascript"></script><script async="" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js" type="text/javascript"></script><script async="" src="//www.google-analytics.com/analytics.js"></script><script async="" src="//confiant-integrations.global.ssl.fastly.net/gpt/202003251303/wrap.js"></script><script type="text/javascript">(window.NREUM||(NREUM={})).loader_config={licenseKey:"37e6a77380",applicationID:"39608998"};window.NREUM||(NREUM={}),__nr_require=function(e,n,t){function r(t){if(!n[t]){var i=n[t]={exports:{}};e[t][0].call(i.exports,function(n){var i=e[t][1][n];return r(i||n)},i,i.exports)}return n[t].exports}if("function"==typeof __nr_require)return __nr_require;for(var i=0;i<t.length;i++)r(t[i]);return r}({1:[function(e,n,t){function r(){}function i(e,n,t){return function(){return o(e,[u.now()].concat(f(arguments)),n?null:this,t),n?void 0:this}}var o=e("handle"),a=e(4),f=e(5),c=e("ee").get("tracer"),u=e("loader"),s=NREUM;"undefined"==typeof window.newrelic&&(newrelic=s);var p=["setPageViewName","setCustomAttribute","setErrorHandler","finished","addToTrace","inlineHit","addRelease"],l="api-",d=l+"ixn-";a(p,function(e,n){s[n]=i(l+n,!0,"api")}),s.addPageAction=i(l+"addPageAction",!0),s.setCurrentRouteName=i(l+"routeName",!0),n.exports=newrelic,s.interaction=function(){return(new r).get()};var m=r.prototype={createTracer:function(e,n){var t={},r=this,i="function"==typeof n;return o(d+"tracer",[u.now(),e,t],r),function(){if(c.emit((i?"":"no-")+"fn-start",[u.now(),r,i],t),i)try{return n.apply(this,arguments)}catch(e){throw c.emit("fn-err",[arguments,this,e],t),e}finally{c.emit("fn-end",[u.now()],t)}}}};a("actionText,setName,setAttribute,save,ignore,onEnd,getContext,end,get".split(","),function(e,n){m[n]=i(d+n)}),newrelic.noticeError=function(e,n){"string"==typeof e&&(e=new Error(e)),o("err",[e,u.now(),!1,n])}},{}],2:[function(e,n,t){function r(e,n){var t=e.getEntries();t.forEach(function(e){"first-paint"===e.name?c("timing",["fp",Math.floor(e.startTime)]):"first-contentful-paint"===e.name&&c("timing",["fcp",Math.floor(e.startTime)])})}function i(e,n){var t=e.getEntries();t.length>0&&c("lcp",[t[t.length-1]])}function o(e){if(e instanceof s&&!l){var n,t=Math.round(e.timeStamp);n=t>1e12?Date.now()-t:u.now()-t,l=!0,c("timing",["fi",t,{type:e.type,fid:n}])}}if(!("init"in NREUM&&"page_view_timing"in N ...
# <meta content="en-us" http-equiv="content-language"/>
# <!-- iOS metadata -->
# <meta content="no" name="apple-mobile-web-app-capable"/>
# <meta content="width=device-width" name="viewport"/>
# <!-- android homescreen specific favicon -->
# <link href="//cdn-gce.allmusic.com/images/favicon/favicon-196x196.png?v=47BXOjEqB" rel="icon" sizes="196x196" type="image/png"/>
# <!-- general favicon -->
# <link href="//cdn-gce.allmusic.com/images/favicon/favicon-96x96.png?v=47BXOjEqB" rel="icon" sizes="96x96" type="image/png"/>
# <link href="//cdn-gce.allmusic.com/images/favicon/favicon-32x32.png?v=47BXOjEqB" rel="icon" sizes="32x32" type="image/png"/>
# <link href="//cdn-gce.allmusic.com/images/favicon/favicon-16x16.png?v=47BXOjEqB" rel="icon" sizes="16x16" type="image/png"/>
# <link href="//cdn-gce.allmusic.com/images/favicon/favicon.ico?v=47BXOjEqB" rel="shortcut icon" type="image/x-icon"/>
# <!-- iOS specific favicons -->
# <link href="//cdn-gce.allmusic.com/images/favicon/ios/apple-touch-icon-120x120.png?v=47BXOjEqB" rel="apple-touch-icon-precomposed" sizes="120x120"/>
# <link href="//cdn-gce.allmusic.com/images/favicon/ios/apple-touch-icon-76x76.png?v=47BXOjEqB" rel="apple-touch-icon-precomposed" sizes="76x76"/>
# <link href="//cdn-gce.allmusic.com/images/favicon/ios/apple-touch-icon-152x152.png?v=47BXOjEqB" rel="apple-touch-icon-precomposed" sizes="152x152"/>
# <link href="//cdn-gce.allmusic.com/images/favicon/ios/apple-touch-icon-180x180.png?v=47BXOjEqB" rel="apple-touch-icon-precomposed" sizes="180x180"/>
# <meta content="AllMusic" name="apple-mobile-web-app-title"/>
# <meta content="AllMusic" name="application-name"/>
# <link href="/rss" rel="alternate" title="RSS" type="application/rss+xml"/>
# <link href="https://chrome.google.com/webstore/detail/kffpbhfpflaacppoegnbknokchggcoao" rel="chrome-webstore-item"/>
# <meta content="Explore Music by Mood | AllMusic" name="title"/>
# <meta content="Romantic, Bittersweet, Druggy, Melancholy, Hypnotic, Aggressive, Sexy" name="keywords"/>
# <meta content="Explore albums and songs by moods on AllMusic" name="description"/>
# <meta content="AllMusic" property="og:site_name"/>
# <meta content="415271808519760" property="fb:app_id"/>
# <meta content="website" property="og:type"/>
# <meta content="Explore Music by Mood | AllMusic" property="og:title"/>
# <meta content="Explore Music by Mood | AllMusic" itemprop="name"/>
# <meta content="Explore Music by Mood | AllMusic" name="twitter:title"/>
# <meta content="Explore albums and songs by moods on AllMusic" property="og:description"/>
# <meta content="Explore albums and songs by moods on AllMusic" itemprop="description"/>
# <meta content="Explore albums and songs by moods on AllMusic" name="twitter:description"/>
# <meta content="//cdn-gce.allmusic.com/images/allmusic_facebook_share.png" property="og:image"/>
# <meta content="https://www.allmusic.com/moods" property="og:url"/>
# <meta content="disable-all" name="spotim-ads"/>
# <link href="https://www.allmusic.com/moods" rel="canonical"/>
# <title>Explore Music by Mood | AllMusic</title>
# <link href="//cdn-gce.allmusic.com/cache/dist/css/global/global-fde3935ff3.css" rel="stylesheet" type="text/css"/>
# <link href="//cdn-gce.allmusic.com/cache/dist/css/pages/descriptor/all-67463783fa.css" rel="stylesheet" type="text/css"/>
# <!-- Alexa tag -->
# <meta content="SfgYrX5roRNK_iy-Mr_tFkRlY7M" name="alexaVerifyID"/>
# <!-- Confiant tag-->
# <script async="" src="https://confiant-integrations.global.ssl.fastly.net/1LTHH6xASXMDHFRDP1KqXZl59ww/gpt_and_prebid/config.js"></script>
# <script>
#         (function (i, s, o, g, r, a, m) {
#             i['GoogleAnalyticsObject'] = r;
#             i[r] = i[r] || function () {
#                 (i[r].q = i[r].q || []).push(arguments)
#             }, i[r].l = 1 * new Date();
#             a = s.createElement(o),
#                 m = s.getElementsByTagName(o)[0];
#             a.async = 1;
#             a.src = g;
#             m.parentNode.insertBefore(a, m)
#         })(window, document, 'script', '//www.google-analytics.com/analytics.js', 'ga');
#         ga('create', 'UA-7096127-1', 'auto');
#
#                         ga('send', 'pageview', 'moods');
#                 setTimeout("ga('send','event','adjusted bounce rate','page visit 15 seconds or more')", 15000);
#             </script>
# <!-- Media query polyfill ( Always require because loading via dynamic ajax injection is too slow [the enquire.js will fire before the ajax completes] ) -->
# <script src="//cdn-gce.allmusic.com/js/lib/media.match.min.js"></script>
# <script src="//cdn-gce.allmusic.com/cache/dist/js/setup-f76142219a.js"></script>
# <script type="text/javascript">
# var Allmusic_ROS_1x1_Footer_slot = null;
# var googletag = googletag || {};
# googletag.cmd = googletag.cmd || [];
# (function(){
#   var gads = document.createElement("script");
#   gads.async = true;
#   gads.type = "text/javascript";
#   var useSSL = "https:" == document.location.protocol;
#   gads.src = (useSSL ? "https:" : "http:") + "//securepubads.g.doubleclick.net/tag/js/gpt.js";
#   var node = document.getElementsByTagName("script")[0];
#   node.parentNode.insertBefore(gads, node);
# })();
# googletag.cmd.push(function(){
#   Allmusic_ROS_1x1_Footer_slot = googletag.defineSlot('/22732481/Allmusic_ROS_1x1_Footer', [[1, 1]], 'Allmusic_ROS_1x1_Footer').addService(googletag.pubads());
# });
# googletag.cmd.push(function(){
#   googletag.pubads().setTargeting('pagename', 'all_moods');
#   googletag.pubads().setTargeting('blockadex', 'FALSE');
# if ( isMobile_AllMusic ) {
#   googletag.pubads().setTargeting('mobile', 'TRUE');
# } else {
#   googletag.pubads().setTargeting('mobile', 'FALSE');
# }
#   googletag.pubads().set("adsense_background_color", "F4F4F4");
#   googletag.pubads().disableInitialLoad();
#   googletag.enableServices();
# });
# </script> <script type="text/javascript">
#    window.CMNUNT_OPTIONS = {async: true};
#    cmnunt_site = 'allmusic';
#    cmnunt_silo = 's_mus';
#    cmnunt_subsilo = '';
#    cmnunt_tier = 'to,t2,subhome';
#    cmnunt_zone = 'discover';
#    cmnunt_kw = 'blockadex=FALSE,pagename=all_moods';
#    cmnunt_exclude = '';
#     var isMobile = /iPhone|iPod|BlackBerry|Opera Mini|(android|bb\d+|meego).+mobile/i.test(navigator.userAgent);
#     (function(){
#         var adScript = document.createElement('script');
#         if(!isMobile){
#             adScript.src = '//media.complex.com/common/cmnUNT.js';
#         }
#         else {
#             adScript.src = '//media.complex.com/common/cmnUNTmobile.js';
#             window.cmnunt_site += '_mob';
#         }
#         adScript.type = 'text/javascript';
#         adScript.async = true;
#         var firstScript = document.getElementsByTagName('script')[0];
#         firstScript.parentNode.insertBefore(adScript, firstScript);
#     }());
# </script>
# <script src="//ajax.googleapis.com/ajax/libs/jquery/2.2.4/jquery.min.js"></script>
# <script>!window.jQuery && document.write(unescape('%3Cscript src="//cdn-gce.allmusic.com/js/jquery/jquery-2.2.4.min.js"%3E%3C/script%3E'))</script>
# <script src="https://ajax.googleapis.com/ajax/libs/jqueryui/1.12.1/jquery-ui.min.js"></script>
# <script>!window.jQuery.ui && document.write(unescape('%3Cscript src="//cdn-gce.allmusic.com/js/jquery/jquery-1.12.1.ui.min.js"%3E%3C/script%3E'))</script>
# <script type="text/javascript">
#         var _qevents = _qevents || [];
#
#         (function () {
#             var elem = document.createElement('script');
#             elem.src = (document.location.protocol == "https:" ? "https://secure" : "http://edge") + ".quantserve.com/quant.js";
#             elem.async = true;
#             elem.type = "text/javascript";
#             var scpt = document.getElementsByTagName('script')[0];
#             scpt.parentNode.insertBefore(elem, scpt);
#         })();
#     </script>
# <!-- Quantcast Choice. Consent Manager Tag -->
# <script async="true" type="text/javascript">
#     var elem = document.createElement('script');
#     elem.src = 'https://quantcast.mgr.consensu.org/cmp.js';
#     elem.async = true;
#     elem.type = "text/javascript";
#     var scpt = document.getElementsByTagName('script')[0];
#     scpt.parentNode.insertBefore(elem, scpt);
#     (function() {
#         var gdprAppliesGlobally = false;
#         function addFrame() {
#             if (!window.frames['__cmpLocator']) {
#                 if (document.body) {
#                     var body = document.body,
#                         iframe = document.createElement('iframe');
#                     iframe.style = 'display:none';
#                     iframe.name = '__cmpLocator';
#                     body.appendChild(iframe);
#                 } else {
#                     // In the case where this stub is located in the head,
#                     // this allows us to inject the iframe more quickly than
#                     // relying on DOMContentLoaded or other events.
#                     setTimeout(addFrame, 5);
#                 }
#             }
#         }
#         addFrame();
#         function cmpMsgHandler(event) {
#             var msgIsString = typeof event.data === "string";
#             var json;
#             if(msgIsString) {
#                 json = event.data.indexOf("__cmpCall") != -1 ? JSON.parse(event.data) : {};
#             } else {
#                 json = event.data;
#             }
#             if (json.__cmpCall) {
#                 var i = json.__cmpCall;
#                 window.__cmp(i.command, i.parameter, function(retValue, success) {
#                     var returnMsg = {"__cmpReturn": {
#                             "returnValue": retValue,
#                             "success": success,
#                             "callId": i.callId
#                         }};
#                     event.source.postMessage(msgIsString ?
#                         JSON.stringify(returnMsg) : returnMsg, '*');
#                 });
#             }
#         }
#         window.__cmp = function (c) {
#             var b = arguments;
#             if (!b.length) {
#                 return __cmp.a;
#             }
#             else if (b[0] === 'ping') {
#                 b[2]({"gdprAppliesGlobally": gdprAppliesGlobally,
#                     "cmpLoaded": false}, true);
#             } else if (c == '__cmp')
#                 return false;
#             else {
#                 if (typeof __cmp.a === 'undefined') {
#                     __cmp.a = [];
#                 }
#                 __cmp.a.push([].slice.apply(b));
#             }
#         }
#         window.__cmp.gdprAppliesGlobally = gdprAppliesGlobally;
#         window.__cmp.msgHandler = cmpMsgHandler;
#         if (window.addEventListener) {
#             window.addEventListener('message', cmpMsgHandler, false);
#         }
#         else {
#             window.attachEvent('onmessage', cmpMsgHandler);
#         }
#     })();
#     window.__cmp('init', {
#         'Language': 'en',
#         'Initial Screen Reject Button Text': 'I do not accept',
#         'Initial Screen Accept Button Text': 'I accept',
#         'Purpose Screen Header Title Text': 'Privacy settings',
#         'Purpose Screen Body Text': 'You can set your consent preferences and determine how you want your data to be used based on the purposes below. You may set your preferences for us independently from those of third-party partners. Each purpose has a description so that you know how we and partners use your data.',
#         'Vendor Screen Body Text': 'You can set consent preferences for each individual third-party company below. Expand each company list item to see what purposes they use data for to help make your choices. In some cases, companies may disclose that they use your data without asking for your consent, based on their legitimate interests. You can click on their privacy policies for more information and to opt out.',
#         'Vendor Screen Accept All Button Text': 'Accept all',
#         'Vendor Screen Reject All Button Text': 'Reject all',
#         'Initial Screen Body Text': 'We and our partners use technology such as cookies on our site to personalise content and ads, provide social media features, and analyse our traffic. Click below to consent to the use of this technology across the web. You can change your mind and change your consent choices at anytime by returning to this site.',
#         'Initial Screen Body Text Option': 1,
#         'Display UI': 'inEU',
#         'UI Layout': '',
#         'Publisher Name': 'AllMusic',
#         'Post Consent Page': '',
#         'Publisher Purpose IDs': [1,2,3,4,5],
#         'Publisher Logo': 'https://cdn-gce.allmusic.com/images/allmusic_150x60.png',
#         'Publisher Purpose Legitimate Interest IDs': [1,2,3,4,5]
#     });
# </script>
# <!-- End Quantcast Choice. Consent Manager Tag -->
# <style>
#     .qc-cmp-button {
#         background-color: #0e76bc  !important;
#         border-color: #0e76bc  !important;
#     }
#     .qc-cmp-button:hover {
#         background-color: transparent !important;
#         border-color: #0e76bc  !important;
#     }
#     .qc-cmp-alt-action,
#     .qc-cmp-link {
#         color: #0e76bc  !important;
#     }
#     .qc-cmp-button.qc-cmp-secondary-button {
#         color: #0e76bc  !important;
#     }
#     .qc-cmp-button.qc-cmp-button.qc-cmp-secondary-button:hover {
#         color:#ffffff !important;
#     }
#     .qc-cmp-button.qc-cmp-secondary-button {
#         border-color: #0e76bc  !important;
#         background-color: transparent !important;
#     }
#     .qc-cmp-button.qc-cmp-secondary-button:hover {
#         background-color: #0e76bc  !important;
#     }
#     .qc-cmp-ui a,
#     .qc-cmp-ui .qc-cmp-alt-action {
#         color: #0e76bc  !important;
#     }
#     .qc-cmp-small-toggle.qc-cmp-toggle-on,
#     .qc-cmp-toggle.qc-cmp-toggle-on {
#         background-color: #0e76bc !important;
#         border-color: #0e76bc !important;
#     }
# </style>
# <style type="text/css">#fdbk_overlay {
#   width: 100%;
#   height: 100%;
#   top: 0;
#   left: 0;
#   z-index: 1000000;
#   position: absolute; }
#
# #fdbk_screen {
#   top: 0;
#   left: 0;
#   z-index: 1;
#   width: 100%;
#   position: absolute;
#   background-color: black;
#   opacity: 0.45;
#   -moz-opacity: 0.45;
#   filter: alpha(opacity=45); }
#
# #fdbk_container {
#   width: 680px;
#   height: 640px;
#   margin: 0 auto;
#   z-index: 2;
#   position: relative; }
#   #fdbk_container iframe {
#     width: 658px;
#     height: 100%;
#     margin: 20px;
#     background: transparent; }
#   #fdbk_container iframe.loading {
#     background: transparent url(https://d37h3y471q0lt2.cloudfront.net/assets/fb_loading-69ae70a0488c96730fb4a43785fd97b7.png) no-repeat; }
#
# a#fdbk_tab {
#   top: 25%;
#   left: 0;
#   width: 42px;
#   height: 102px;
#   color: white;
#   cursor: pointer;
#   text-indent: -100000px;
#   overflow: hidden;
#   position: fixed;
#   z-index: 100000;
#   margin-left: -7px;
#   background-image: url(https://d37h3y471q0lt2.cloudfront.net/assets/feedback_trans_tab-fa5bd26fde4425fd8102f4380980fc11.png);
#   _position: absolute;
#   _background-image: url(https://d37h3y471q0lt2.cloudfront.net/assets/feedback_tab_ie6-5de9693842b993553b7b7e3c443ff75e.png); }
#   a#fdbk_tab:hover {
#     margin-left: -4px; }
#
# a.fdbk_tab_right {
#   right: 0 !important;
#   left: auto !important;
#   margin-right: 0 !important;
#   margin-left: auto !important;
#   width: 35px !important; }
#   a.fdbk_tab_right:hover {
#     width: 38px !important;
#     margin-right: 0 !important;
#     margin-left: auto !important; }
#
# a.fdbk_tab_bottom {
#   top: auto !important;
#   bottom: 0 !important;
#   left: 20% !important;
#   height: 38px !important;
#   width: 102px !important;
#   background-position: 0 -102px !important;
#   margin-bottom: -7px !important;
#   margin-left: auto !important; }
#   a.fdbk_tab_bottom:hover {
#     margin-bottom: -4px !important;
#     margin-left: auto !important; }
#
# a.fdbk_tab_hidden {
#   display: none !important; }
#
# a#fdbk_close {
#   position: absolute;
#   cursor: pointer;
#   outline: none;
#   top: 0;
#   left: 0;
#   z-index: 4;
#   width: 42px;
#   height: 42px;
#   overflow: hidden;
#   background-image: url(https://dv4uxy777adjt.cloudfront.net/assets/feedback-close-28150549f7cfbad294bff4e64334c01a.png);
#   _background: none;
#   _filter: progid:DXImageTransform.Microsoft.AlphaImageLoader(src="https://dv4uxy777adjt.cloudfront.net/assets/feedback-close-28150549f7cfbad294bff4e64334c01a.png", sizingMethod='crop'); }
#   a#fdbk_close:hover {
#     background-position: -42px 0; }
#
# .feedback_tab_on embed, .feedback_tab_on select, .feedback_tab_on object {
#   visibility: hidden; }
# </style><style type="text/css">#cmn_ad_tag_head, #cmn_ad_tag_head div, #cmn_ad_tag_head table, #cmn_ad_tag_head table td {margin: 0 auto; text-align:center;}</style><link as="script" href="https://adservice.google.com/adsid/integrator.js?domain=www.allmusic.com" rel="preload"/><script src="https://adservice.google.com/adsid/integrator.js?domain=www.allmusic.com" type="text/javascript"></script><script async="" src="https://securepubads.g.doubleclick.net/gpt/pubads_impl_2020032401.js?21065778"></script><link href="//toolbar.complex.com/css/ctoolbar.desktop.min.css" rel="stylesheet" type="text/css"/><style>.inview-level-0.tynt-lazyboy {z-index: 19999!important;}</style><script src="https://s.cpx.to/fire.js?pid=12023&amp;ref=&amp;hn_ver=10&amp;fid=b1539b76-dc4b-419e-8dc8-da22b54725aa"></script><link href="https://cdn-sic.33across.com/1/stylesheets/sic.css" rel="stylesheet" type="text/css"/><script async="" src="https://sic.33across.com/authorize?gdprConsentLength=0&amp;version=2.62.0&amp;agent=Mozilla%2F5.0%20(Macintosh%3B%20Intel%20Mac%20OS%20X%2010.15%3B%20rv%3A74.0)%20Gecko%2F20100101%20Firefox%2F74.0&amp;product=inview&amp;userId=&amp;sessionId=&amp;publisherURL=https%3A%2F%2Fwww.allmusic.com%2Fmoods&amp;referrerURL=&amp;publisherId=dXE5DyVPKr6yb7aKlId8sQ&amp;publisher=allmusic.com_impact&amp;viewportWidth=1265&amp;viewportHeight=803&amp;screenWidth=1680&amp;screenHeight=1050&amp;scrollX=0&amp;scrollY=0&amp;pageVisibility=visible&amp;pageWidth=1265&amp;pageHeight=2762&amp;_=1585434559190&amp;callback=_tynt_jp.a5rr22mex" type="text/javascript"></script></head>
# <body><iframe frameborder="0" id="tynt-ox-iframe-3" style="position: absolute; visibility: hidden; width: 1px; height: 1px;"></iframe><iframe frameborder="0" id="tynt-ox-iframe-2" style="position: absolute; visibility: hidden; width: 1px; height: 1px;"></iframe><iframe frameborder="0" id="tynt-ox-iframe-1" style="position: absolute; visibility: hidden; width: 1px; height: 1px;"></iframe><iframe frameborder="0" id="tynt-apn-ast-container" style="position: absolute; visibility: hidden; width: 1px; height: 1px;"></iframe><div class="tynt-viewability"></div>
# <div class="tynt-ad-fence tynt-ad-fence-startpos-left" style="display:inline-block; position:absolute; margin:-10px; left:0; top:0" tynt-data="no-content">
# <div class="tynt-ad-container" hs-name="lazyboy-rising-star" id="tynt-ad-2kwkle9x" style="display:inline-block; padding:10px">
# <div class="inview-level-0 tynt-lazyboy">
# <div class="inview-level-1" style="transform: translateY(-100%); padding-bottom: 55px;">
# <div class="tynt-close-btn-container">
# <div class="tynt-close-btn" hs-name="Close Button">
#          × Close Ad
#       </div>
# </div> <div class="tynt-ad-frame-container" style="width: 728px; height: 90px;"><iframe class="tynt-ad-frame" frameborder="0" scrolling="no" style="width: 728px; height: 90px;"></iframe></div>
# </div>
# </div>
# </div>
# </div><iframe frameborder="0" id="tynt-gpt-iframe-1" style="position: absolute; visibility: hidden; width: 1px; height: 1px;"></iframe>
# <noscript>
# <div class="javascript-disabled" id="no-js">
#         AllMusic relies heavily on JavaScript.<br/>
#         Please enable JavaScript in your browser to use the site fully.
#     </div>
# </noscript>
# <div class="stripe-container header-leaderboard" style="margin-bottom: 0px;">
# <div class="advertising leaderboard">
# <div class="fw_allmusic" id="cmn_ad_tag_head"><div id="complex_leaderboard_header"></div></div> </div>
# </div>
# <div class="overflow-container all_moods">
# <div class="stripe-container header-main-nav clearfix">
# <div class="max-header">
# <div class="main-nav">
# <div class="logo-container">
# <a class="logo no-snap" href="/">
# <h3 class="logo-img">AllMusic</h3>
# </a>
# </div>
# <nav class="mobile-menu"></nav>
# <div class="search-container">
# <form action="/search" class="site-search" method="post" name="site-search">
# <input autocomplete="off" class="site-search-input" name="term" placeholder="Search" tabindex="1" type="search"/><div class="allmusic-typeahead" style="display: none; position: absolute; top: 53px; left: 808.5px;"><div class="typeahead-results searching"><span class="typeahead-searching-msg" style=""><h3 style="color:#A9A9A9;">Searching<span class="dots">..</span></h3></span></div><div class="see-all"></div></div>
# <input class="site-search-button" name="submit" type="submit" value=""/>
# </form>
# </div>
# <nav class="site-nav">
# <ul>
# <li class="new-releases">
# <a href="/newreleases">New Releases</a>
# <ul class="new-releases-nav">
# <div class="sub-nav-container">
# <div class="sub-nav-columns">
# <div class="new-releases-subnav left">
# <li class="nr-featured">
# <a href="/newreleases">Featured New Releases</a>
# </li>
# <li class="nr-editorschoice">
# <a href="/newreleases/editorschoice">Editors' Choice</a>
# </li>
# <li class="nr-all">
# <a href="/newreleases/all">All New Releases</a>
# </li>
# </div>
# <div class="new-releases-subnav right">
# <div class="sub-nav-content">
# </div>
# </div>
# </div>
# </div>
# </ul> </li>
# <li class="discover">
# <a href="/discover">Discover</a>
# <ul class="discover-nav">
# <div class="sub-nav-container">
# <div class="sub-nav-columns left">
# <li class="discover-drop-trigger active" id="discover-genres">
# <a href="/genres">Genres<span class="genres-arrow" style="display:none">  ›</span></a>
# </li>
# <li class="discover-drop-trigger" id="discover-moods">
# <a href="/moods">Moods<span class="moods-arrow" style="display:none">  ›</span></a>
# </li>
# <li class="discover-drop-trigger" id="discover-themes">
# <a href="/themes">Themes<span class="themes-arrow" style="display:none">  ›</span></a>
# </li>
# </div>
# <div class="sub-nav-columns right">
# <ul class="discover-genre-secondary">
# <div class="genre-column">
# <!-- spacer to prevent hover weirdness -->
# </div>
# <div class="genre-column">
# <li class="individual">
# <a href="/genre/blues-ma0000002467">Blues</a>
# </li>
# <li class="individual">
# <a href="/genre/classical-ma0000002521">Classical</a>
# </li>
# <li class="individual">
# <a href="/genre/country-ma0000002532">Country</a>
# </li>
# </div>
# <div class="genre-column">
# <li class="individual">
# <a href="/genre/electronic-ma0000002572">Electronic</a>
# </li>
# <li class="individual">
# <a href="/genre/folk-ma0000002592">Folk</a>
# </li>
# <li class="individual">
# <a href="/genre/international-ma0000002660">International</a>
# </li>
# </div>
# <div class="genre-column">
# <li class="individual">
# <a href="/genre/jazz-ma0000002674">Jazz</a>
# </li>
# <li class="individual">
# <a href="/genre/latin-ma0000002692">Latin</a>
# </li>
# <li class="individual">
# <a href="/genre/new-age-ma0000002745">New Age</a>
# </li>
# </div>
# <div class="genre-column">
# <li class="individual">
# <a href="/genre/pop-rock-ma0000002613">Pop/Rock</a>
# </li>
# <li class="individual">
# <a href="/genre/rap-ma0000002816">Rap</a>
# </li>
# <li class="individual">
# <a href="/genre/r-b-ma0000002809">R&amp;B</a>
# </li>
# </div>
# <div class="genre-column">
# <li class="individual">
# <a href="/genre
# </li>
# <li class="blog-all">
# <a href="/blog">All Posts</a>
# </li>
# </div>
# <div class="blog-subnav right">
# <div class="sub-nav-blog-content"></div>
# </div>
# </div>
# </div>
# </ul>
# </li>
# <!--            <li class="videos">-->
# <!--                <a href="/videos" class="videos-link">Video</a>-->
# <!--            </li>-->
# <li class="recommendations">
# <a href="/recommendations">Recommendations</a>
# </li>
# <li class="my-profile">
# <a class="my-profile-link" href="javascript:void(0)">My Profile</a>
# </li>
# <li class="advanced-search">
# <a class="advanced-search-link" href="/advanced-search">Advanced Search</a>
# </li>
# </ul>
# </nav>
# <div class="user-social-nav">
# <nav class="social-nav">
# <ul>
# <li class="facebook">
# <a alt="Like us on Facebook" href="https://www.facebook.com/AllMusicDotCom" title="Like us on Facebook">Facebook</a>
# </li>
# <li class="twitter">
# <a alt="Follow us on Twitter" href="https://twitter.com/#!/Allmusic" title="Follow us on Twitter">Twitter</a>
# </li>
# <li class="tumblr">
# <a alt="Follow us on Tumblr" href="https://allmusic.tumblr.com" title="Follow us on Tumblr">Tumblr</a>
# </li>
# <li class="rss">
# <a alt="Subscribe to our RSS feed" href="/rss" target="_blank" title="Subscribe to our RSS feed">RSS</a>
# </li>
# </ul>
# </nav>
# <nav class="user-notifications">
# <ul>
# <li class="user-notification-icon">
# </li>
# </ul>
# </nav>
# <nav class="user-nav"> <ul class="user-nav-not-logged-in">
# <li class="user-sign-up">
# <a href="/join">Sign Up</a>
# </li>
# <li class="user-nav-divider-line">|</li>
# <li class="user-log-in">
# <a class="open-login-modal" href="#">Log in</a>
# </li>
# </ul>
# </nav>
# </div>
# </div> </div>
# </div>
# <div id="cmn_wrap">
# <div class="content-container">
# <div class="content">
# <div class="allmusic-share" data-sharemessage="Check out Music Moods on AllMusic - ">
# <p>
#         Share on
#     </p>
# <ul class="share-menu">
# <li>
# <a class="share-button facebook" href="https://www.facebook.com/sharer.php?u=https%3A%2F%2Fwww.allmusic.com%2Fmoods" title="Share on Facebook">facebook</a>
# </li>
# <li>
# <a class="share-button twitter" href="https://twitter.com/share?url=https%3A%2F%2Fwww.allmusic.com%2Fmoods&amp;text=Check+out+Music+Moods+on+AllMusic+-+&amp;counturl=https%3A%2F%2Fwww.allmusic.com%2Fmoods" title="Share on Twitter">twitter</a>
# </li>
# <li>
# <a class="share-button tumblr" href="https://www.tumblr.com/share?s=&amp;v=3&amp;t=AllMusic+%7C+Music+Search%2C+Recommendations%2C+Videos+and+Review&amp;u=https%3A%2F%2Fwww.allmusic.com%2Fmoods" title="Share on Tumblr">tumblr</a>
# </li>
# </ul>
# <div class="share-modal">
# <a class="close-button" title="close button"></a>
# <div class="share-frame"></div>
# </div>
# </div>
# <h1 class="headline">
#                 Moods
#             </h1>
# <div class="mood-container">
# <ul class="mood-list">
# <li>
# <h2><a href="https://www.allmusic.com/mood/acerbic-xa0000000931">Acerbic</a></h2>
# </li>
# <li>
# <h2><a href="https://www.allmusic.com/mood/aggressive-xa0000000694">Aggressive</a></h2>
# </li>
# <li>
# <h2><a href="https://www.allmusic.com/mood/agreeable-xa0000000715">Agreeable</a></h2>
# </li>
# <li>
# <h2><a href="https://www.allmusic.com/mood/airy-xa0000000932">Airy</a></h2>
# </li>
# <li>
# <h2><a href="https://www.allmusic.com/mood/ambitious-xa0000000933">Ambitious</a></h2>
# </li>
# <li>
# <h2><a href="https://www.allmusic.com/mood/amiable-good-natured-xa0000000934">Amiable/Good-Natured</a></h2>
# </li>
# <li>
# <h2><a href="https://www.allmusic.com/mood
type="text/javascript"></script><script async="" src="https://sb.scorecardresearch.com/beacon.js"></script><script src="https://securepubads.g.doubleclick.net/tag/js/gpt.js"></script><script async="" src="https://ssl.google-analytics.com/ga.js"></script><script async="" src="//js-sec.indexww.com/ht/p/184233-278587170399516.js"></script><script async="" src="//c.amazon-adsystem.com/aax2/apstag.js"></script><script async="" src="https://quantcast.mgr.consensu.org/cmp.js" type="text/javascript"></script><script async="" src="https://secure.quantserve.com/quant.js" type="text/javascript"></script><script async="" src="//media.complex.com/common/cmnUNT.js" type="text/javascript"></script><script async="" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js" type="text/javascript"></script><script async="" src="//www.google-analytics.com/analytics.js"></script><script type="text/javascript">(window.NREUM||(NREUM={})).loader_config={licenseKey:"37e6a77380",applicationID:"39608998"};window.NREUM||(NREUM={}),__nr_require=function(e,n,t){function r(t){if(!n[t]){var i=n[t]={exports:{}};e[t][0].call(i.exports,function(n){var i=e[t][1][n];return r(i||n)},i,i.exports)}return n[t].exports}if("function"==typeof __nr_require)return __nr_require;for(var i=0;i<t.length;i++)r(t[i]);return r}({1:[function(e,n,t){function r(){}function i(e,n,t){return function(){return o(e,[u.now()].concat(f(arguments)),n?null:this,t),n?void 0:this}}var o=e("handle"),a=e(4),f=e(5),c=e("ee").get("tracer"),u=e("loader"),s=NREUM;"undefined"==typeof window.newrelic&&(newrelic=s);var p=["setPageViewName","setCustomAttribute","setErrorHandler","finished","addToTrace","inlineHit","addRelease"],l="api-",d=l+"ixn-";a(p,function(e,n){s[n]=i(l+n,!0,"api")}),s.addPageAction=i(l+"addPageAction",!0),s.setCurrentRouteName=i(l+"routeName",!0),n.exports=newrelic,s.interaction=function(){return(new r).get()};var m=r.prototype={createTracer:function(e,n){var t={},r=this,i="function"==typeof n;return o(d+"tracer",[u.now(),e,t],r),function(){if(c.emit((i?"":"no-")+"fn-start",[u.now(),r,i],t),i)try{return n.apply(this,arguments)}catch(e){throw c.emit("fn-err",[arguments,this,e],t),e}finally{c.emit("fn-end",[u.now()],t)}}}};a("actionText,setName,setAttribute,save,ignore,onEnd,getContext,end,get".split(","),function(e,n){m[n]=i(d+n)}),newrelic.noticeError=function(e,n){"string"==typeof e&&(e=new Error(e)),o("err",[e,u.now(),!1,n])}},{}],2:[function(e,n,t){function r(e,n){var t=e.getEntries();t.forEach(function(e){"first-paint"===e.name?c("timing",["fp",Math.floor(e.startTime)]):"first-contentful-paint"===e.name&&c("timing",["fcp",Math.floor(e.startTime)])})}function i(e,n){var t=e.getEntries();t.length>0&&c("lcp",[t[t.length-1]])}function o(e){if(e instanceof s&&!l){var n,t=Math.round(e.timeStamp);n=t>1e12?Date.now()-t:u.now()-t,l=!0,c("ti ...
# <meta content="en-us" http-equiv="content-language"/>
# <!-- iOS metadata -->
# <meta content="no" name="apple-mobile-web-app-capable"/>
# <meta content="width=device-width" name="viewport"/>
# <!-- android homescreen specific favicon -->
# <link href="//cdn-gce.allmusic.com/images/favicon/favicon-196x196.png?v=47BXOjEqB" rel="icon" sizes="196x196" type="image/png"/>
# <!-- general favicon -->
# <link href="//cdn-gce.allmusic.com/images/favicon/favicon-96x96.png?v=47BXOjEqB" rel="icon" sizes="96x96" type="image/png"/>
# <link href="//cdn-gce.allmusic.com/images/favicon/favicon-32x32.png?v=47BXOjEqB" rel="icon" sizes="32x32" type="image/png"/>
# <link href="//cdn-gce.allmusic.com/images/favicon/favicon-16x16.png?v=47BXOjEqB" rel="icon" sizes="16x16" type="image/png"/>
# <link href="//cdn-gce.allmusic.com/images/favicon/favicon.ico?v=47BXOjEqB" rel="shortcut icon" type="image/x-icon"/>
# <!-- iOS specific favicons -->
# <link href="//cdn-gce.allmusic.com/images/favicon/ios/apple-touch-icon-120x120.png?v=47BXOjEqB" rel="apple-touch-icon-precomposed" sizes="120x120"/>
# <link href="//cdn-gce.allmusic.com/images/favicon/ios/apple-touch-icon-76x76.png?v=47BXOjEqB" rel="apple-touch-icon-precomposed" sizes="76x76"/>
# <link href="//cdn-gce.allmusic.com/images/favicon/ios/apple-touch-icon-152x152.png?v=47BXOjEqB" rel="apple-touch-icon-precomposed" sizes="152x152"/>
# <link href="//cdn-gce.allmusic.com/images/favicon/ios/apple-touch-icon-180x180.png?v=47BXOjEqB" rel="apple-touch-icon-precomposed" sizes="180x180"/>
# <meta content="AllMusic" name="apple-mobile-web-app-title"/>
# <meta content="AllMusic" name="application-name"/>
# <link href="/rss" rel="alternate" title="RSS" type="application/rss+xml"/>
# <link href="https://chrome.google.com/webstore/detail/kffpbhfpflaacppoegnbknokchggcoao" rel="chrome-webstore-item"/>
# <meta content="Acerbic Music Mood Overview | AllMusic" name="title"/>
# <meta content="Acerbic,Acerbic music,Acerbic artists,Acerbic songs,representative Acerbic albums,representative Acerbic artists,representative Acerbic songs,recent Acerbic album releases" name="keywords"/>
# <meta content="Find Acerbic Albums, Songs, and Hand-Picked Acerbic Mood Music on AllMusic" name="description"/>
# <meta content="AllMusic" property="og:site_name"/>
# <meta content="415271808519760" property="fb:app_id"/>
# <meta content="website" property="og:type"/>
# <meta content="Acerbic Music Mood Overview | AllMusic" property="og:title"/>
# <meta content="Acerbic Music Mood Overview | AllMusic" itemprop="name"/>
# <meta content="Acerbic Music Mood Overview | AllMusic" name="twitter:title"/>
# <meta content="Find Acerbic Albums, Songs, and Hand-Picked Acerbic Mood Music on AllMusic" property="og:description"/>
# <meta content="Find Acerbic Albums, Songs, and Hand-Picked Acerbic Mood Music on AllMusic" itemprop="description"/>
# <meta content="Find Acerbic Albums, Songs, and Hand-Picked Acerbic Mood Music on AllMusic" name="twitter:description"/>
# <meta content="//cdn-gce.allmusic.com/images/allmusic_facebook_share.png" property="og:image"/>
# <meta content="https://www.allmusic.com/mood/acerbic-xa0000000931" property="og:url"/>
# <meta content="disable-all" name="spotim-ads"/>
# <link href="https://www.allmusic.com/mood/acerbic-xa0000000931" rel="canonical"/>
# <title>Acerbic Music Mood Overview | AllMusic</title>
# <link href="//cdn-gce.allmusic.com/cache/dist/css/global/global-fde3935ff3.css" rel="stylesheet" type="text/css"/>
# <link href="//cdn-gce.allmusic.com/cache/dist/css/pages/descriptor/descriptor-61278efe23.css" rel="stylesheet" type="text/css"/>
# <!-- Alexa tag -->
# <meta content="SfgYrX5roRNK_iy-Mr_tFkRlY7M" name="alexaVerifyID"/>
# <!-- Confiant tag-->
# <script async="" src="https://confiant-integrations.global.ssl.fastly.net/1LTHH6xASXMDHFRDP1KqXZl59ww/gpt_and_prebid/config.js"></script>
# <script>
#         (function (i, s, o, g, r, a, m) {
#             i['GoogleAnalyticsObject'] = r;
#             i[r] = i[r] || function () {
#                 (i[r].q = i[r].q || []).push(arguments)
#             }, i[r].l = 1 * new Date();
#             a = s.createElement(o),
#                 m = s.getElementsByTagName(o)[0];
#             a.async = 1;
#             a.src = g;
#             m.parentNode.insertBefore(a, m)
#         })(window, document, 'script', '//www.google-analytics.com/analytics.js', 'ga');
#         ga('create', 'UA-7096127-1', 'auto');
#
#                         ga('send', 'pageview', 'mood/acerbic-xa0000000931');
#                 setTimeout("ga('send','event','adjusted bounce rate','page visit 15 seconds or more')", 15000);
#             </script>
# <!-- Media query polyfill ( Always require because loading via dynamic ajax injection is too slow [the enquire.js will fire before the ajax completes] ) -->
# <script src="//cdn-gce.allmusic.com/js/lib/media.match.min.js"></script>
# <script src="//cdn-gce.allmusic.com/cache/dist/js/setup-f76142219a.js"></script>
# <script type="text/javascript">
# var Allmusic_ROS_1x1_Footer_slot = null;
# var AllMusic_Saambaa_1x1_slot = null;
# var googletag = googletag || {};
# googletag.cmd = googletag.cmd || [];
# (function(){
#   var gads = document.createElement("script");
#   gads.async = true;
#   gads.type = "text/javascript";
#   var useSSL = "https:" == document.location.protocol;
#   gads.src = (useSSL ? "https:" : "http:") + "//securepubads.g.doubleclick.net/tag/js/gpt.js";
#   var node = document.getElementsByTagName("script")[0];
#   node.parentNode.insertBefore(gads, node);
# })();
# googletag.cmd.push(function(){
#   Allmusic_ROS_1x1_Footer_slot = googletag.defineSlot('/22732481/Allmusic_ROS_1x1_Footer', [[1, 1]], 'Allmusic_ROS_1x1_Footer').addService(googletag.pubads());
# });
# googletag.cmd.push(function(){
#   AllMusic_Saambaa_1x1_slot = googletag.defineSlot('/22732481/AllMusic_Saambaa_1x1', [[300, 350]], 'AllMusic_Saambaa_1x1').addService(googletag.pubads());
# });
# googletag.cmd.push(function(){
#   googletag.pubads().setTargeting('pagename', 'mood');
#   googletag.pubads().setTargeting('blockadex', 'TRUE');
# if ( isMobile_AllMusic ) {
#   googletag.pubads().setTargeting('mobile', 'TRUE');
# } else {
#   googletag.pubads().setTargeting('mobile', 'FALSE');
# }
#   googletag.pubads().set("adsense_background_color", "F4F4F4");
#   googletag.pubads().disableInitialLoad();
#   googletag.enableServices();
# });
# </script> <script type="text/javascript">
#    window.CMNUNT_OPTIONS = {async: true};
#    cmnunt_site = 'allmusic';
#    cmnunt_silo = 's_mus';
#    cmnunt_subsilo = '';
#    cmnunt_tier = 'to,t2,subhome';
#    cmnunt_zone = 'discover';
#    cmnunt_kw = 'blockadex=TRUE,pagename=mood';
#    cmnunt_exclude = '';
#     var isMobile = /iPhone|iPod|BlackBerry|Opera Mini|(android|bb\d+|meego).+mobile/i.test(navigator.userAgent);
#     (function(){
#         var adScript = document.createElement('script');
#         if(!isMobile){
#             adScript.src = '//media.complex.com/common/cmnUNT.js';
#         }
#         else {
#             adScript.src = '//media.complex.com/common/cmnUNTmobile.js';
#             window.cmnunt_site += '_mob';
#         }
#         adScript.type = 'text/javascript';
#         adScript.async = true;
#         var firstScript = document.getElementsByTagName('script')[0];
#         firstScript.parentNode.insertBefore(adScript, firstScript);
#     }());
# </script>
# <script src="//ajax.googleapis.com/ajax/libs/jquery/2.2.4/jquery.min.js"></script>
# <script>!window.jQuery && document.write(unescape('%3Cscript src="//cdn-gce.allmusic.com/js/jquery/jquery-2.2.4.min.js"%3E%3C/script%3E'))</script>
# <script src="https://ajax.googleapis.com/ajax/libs/jqueryui/1.12.1/jquery-ui.min.js"></script>
# <script>!window.jQuery.ui && document.write(unescape('%3Cscript src="//cdn-gce.allmusic.com/js/jquery/jquery-1.12.1.ui.min.js"%3E%3C/script%3E'))</script>
# <script type="text/javascript">
#         var _qevents = _qevents || [];
#
#         (function () {
#             var elem = document.createElement('script');
#             elem.src = (document.location.protocol == "https:" ? "https://secure" : "http://edge") + ".quantserve.com/quant.js";
#             elem.async = true;
#             elem.type = "text/javascript";
#             var scpt = document.getElementsByTagName('script')[0];
#             scpt.parentNode.insertBefore(elem, scpt);
#         })();
#     </script>
# <!-- Quantcast Choice. Consent Manager Tag -->
# <script async="true" type="text/javascript">
#     var elem = document.createElement('script');
#     elem.src = 'https://quantcast.mgr.consensu.org/cmp.js';
#     elem.async = true;
#     elem.type = "text/javascript";
#     var scpt = document.getElementsByTagName('script')[0];
#     scpt.parentNode.insertBefore(elem, scpt);
#     (function() {
#         var gdprAppliesGlobally = false;
#         function addFrame() {
#             if (!window.frames['__cmpLocator']) {
#                 if (document.body) {
#                     var body = document.body,
#                         iframe = document.createElement('iframe');
#                     iframe.style = 'display:none';
#                     iframe.name = '__cmpLocator';
#                     body.appendChild(iframe);
#                 } else {
#                     // In the case where this stub is located in the head,
#                     // this allows us to inject the iframe more quickly than
#                     // relying on DOMContentLoaded or other events.
#                     setTimeout(addFrame, 5);
#                 }
#             }
#         }
#         addFrame();
#         function cmpMsgHandler(event) {
#             var msgIsString = typeof event.data === "string";
#             var json;
#             if(msgIsString) {
#                 json = event.data.indexOf("__cmpCall") != -1 ? JSON.parse(event.data) : {};
#             } else {
#                 json = event.data;
#             }
#             if (json.__cmpCall) {
#                 var i = json.__cmpCall;
#                 window.__cmp(i.command, i.parameter, function(retValue, success) {
#                     var returnMsg = {"__cmpReturn": {
#                             "returnValue": retValue,
#                             "success": success,
#                             "callId": i.callId
#                         }};
#                     event.source.postMessage(msgIsString ?
#                         JSON.stringify(returnMsg) : returnMsg, '*');
#                 });
#             }
#         }
#         window.__cmp = function (c) {
#             var b = arguments;
#             if (!b.length) {
#                 return __cmp.a;
#             }
#             else if (b[0] === 'ping') {
#                 b[2]({"gdprAppliesGlobally": gdprAppliesGlobally,
#                     "cmpLoaded": false}, true);
#             } else if (c == '__cmp')
#                 return false;
#             else {
#                 if (typeof __cmp.a === 'undefined') {
#                     __cmp.a = [];
#                 }
#                 __cmp.a.push([].slice.apply(b));
#             }
#         }
#         window.__cmp.gdprAppliesGlobally = gdprAppliesGlobally;
#         window.__cmp.msgHandler = cmpMsgHandler;
#         if (window.addEventListener) {
#             window.addEventListener('message', cmpMsgHandler, false);
#         }
#         else {
#             window.attachEvent('onmessage', cmpMsgHandler);
#         }
#     })();
#     window.__cmp('init', {
#         'Language': 'en',
#         'Initial Screen Reject Button Text': 'I do not accept',
#         'Initial Screen Accept Button Text': 'I accept',
#         'Purpose Screen Header Title Text': 'Privacy settings',
#         'Purpose Screen Body Text': 'You can set your consent preferences and determine how you want your data to be used based on the purposes below. You may set your preferences for us independently from those of third-party partners. Each purpose has a description so that you know how we and partners use your data.',
#         'Vendor Screen Body Text': 'You can set consent preferences for each individual third-party company below. Expand each company list item to see what purposes they use data for to help make your choices. In some cases, companies may disclose that they use your data without asking for your consent, based on their legitimate interests. You can click on their privacy policies for more information and to opt out.',
#         'Vendor Screen Accept All Button Text': 'Accept all',
#         'Vendor Screen Reject All Button Text': 'Reject all',
#         'Initial Screen Body Text': 'We and our partners use technology such as cookies on our site to personalise content and ads, provide social media features, and analyse our traffic. Click below to consent to the use of this technology across the web. You can change your mind and change your consent choices at anytime by returning to this site.',
#         'Initial Screen Body Text Option': 1,
#         'Display UI': 'inEU',
#         'UI Layout': '',
#         'Publisher Name': 'AllMusic',
#         'Post Consent Page': '',
#         'Publisher Purpose IDs': [1,2,3,4,5],
#         'Publisher Logo': 'https://cdn-gce.allmusic.com/images/allmusic_150x60.png',
#         'Publisher Purpose Legitimate Interest IDs': [1,2,3,4,5]
#     });
# </script>
# <!-- End Quantcast Choice. Consent Manager Tag -->
# <style>
#     .qc-cmp-button {
#         background-color: #0e76bc  !important;
#         border-color: #0e76bc  !important;
#     }
#     .qc-cmp-button:hover {
#         background-color: transparent !important;
#         border-color: #0e76bc  !important;
#     }
#     .qc-cmp-alt-action,
#     .qc-cmp-link {
#         color: #0e76bc  !important;
#     }
#     .qc-cmp-button.qc-cmp-secondary-button {
#         color: #0e76bc  !important;
#     }
#     .qc-cmp-button.qc-cmp-button.qc-cmp-secondary-button:hover {
#         color:#ffffff !important;
#     }
#     .qc-cmp-button.qc-cmp-secondary-button {
#         border-color: #0e76bc  !important;
#         background-color: transparent !important;
#     }
#     .qc-cmp-button.qc-cmp-secondary-button:hover {
#         background-color: #0e76bc  !important;
#     }
#     .qc-cmp-ui a,
#     .qc-cmp-ui .qc-cmp-alt-action {
#         color: #0e76bc  !important;
#     }
#     .qc-cmp-small-toggle.qc-cmp-toggle-on,
#     .qc-cmp-toggle.qc-cmp-toggle-on {
#         background-color: #0e76bc !important;
#         border-color: #0e76bc !important;
#     }
# </style>
# <style type="text/css">#fdbk_overlay {
#   width: 100%;
#   height: 100%;
#   top: 0;
#   left: 0;
#   z-index: 1000000;
#   position: absolute; }
#
# #fdbk_screen {
#   top: 0;
#   left: 0;
#   z-index: 1;
#   width: 100%;
#   position: absolute;
#   background-color: black;
#   opacity: 0.45;
#   -moz-opacity: 0.45;
#   filter: alpha(opacity=45); }
#
# #fdbk_container {
#   width: 680px;
#   height: 640px;
#   margin: 0 auto;
#   z-index: 2;
#   position: relative; }
#   #fdbk_container iframe {
#     width: 658px;
#     height: 100%;
#     margin: 20px;
#     background: transparent; }
#   #fdbk_container iframe.loading {
#     background: transparent url(https://d37h3y471q0lt2.cloudfront.net/assets/fb_loading-69ae70a0488c96730fb4a43785fd97b7.png) no-repeat; }
#
# a#fdbk_tab {
#   top: 25%;
#   left: 0;
#   width: 42px;
#   height: 102px;
#   color: white;
#   cursor: pointer;
#   text-indent: -100000px;
#   overflow: hidden;
#   position: fixed;
#   z-index: 100000;
#   margin-left: -7px;
#   background-image: url(https://d37h3y471q0lt2.cloudfront.net/assets/feedback_trans_tab-fa5bd26fde4425fd8102f4380980fc11.png);
#   _position: absolute;
#   _background-image: url(https://d37h3y471q0lt2.cloudfront.net/assets/feedback_tab_ie6-5de9693842b993553b7b7e3c443ff75e.png); }
#   a#fdbk_tab:hover {
#     margin-left: -4px; }
#
# a.fdbk_tab_right {
#   right: 0 !important;
#   left: auto !important;
#   margin-right: 0 !important;
#   margin-left: auto !important;
#   width: 35px !important; }
#   a.fdbk_tab_right:hover {
#     width: 38px !important;
#     margin-right: 0 !important;
#     margin-left: auto !important; }
#
# a.fdbk_tab_bottom {
#   top: auto !important;
#   bottom: 0 !important;
#   left: 20% !important;
#   height: 38px !important;
#   width: 102px !important;
#   background-position: 0 -102px !important;
#   margin-bottom: -7px !important;
#   margin-left: auto !important; }
#   a.fdbk_tab_bottom:hover {
#     margin-bottom: -4px !important;
#     margin-left: auto !important; }
#
# a.fdbk_tab_hidden {
#   display: none !important; }
#
# a#fdbk_close {
#   position: absolute;
#   cursor: pointer;
#   outline: none;
#   top: 0;
#   left: 0;
#   z-index: 4;
#   width: 42px;
#   height: 42px;
#   overflow: hidden;
#   background-image: url(https://dv4uxy777adjt.cloudfront.net/assets/feedback-close-28150549f7cfbad294bff4e64334c01a.png);
#   _background: none;
#   _filter: progid:DXImageTransform.Microsoft.AlphaImageLoader(src="https://dv4uxy777adjt.cloudfront.net/assets/feedback-close-28150549f7cfbad294bff4e64334c01a.png", sizingMethod='crop'); }
#   a#fdbk_close:hover {
#     background-position: -42px 0; }
#
# .feedback_tab_on embed, .feedback_tab_on select, .feedback_tab_on object {
#   visibility: hidden; }
# </style><style type="text/css">#cmn_ad_tag_head, #cmn_ad_tag_head div, #cmn_ad_tag_head table, #cmn_ad_tag_head table td {margin: 0 auto; text-align:center;}</style><link as="script" href="https://adservice.google.com/adsid/integrator.js?domain=www.allmusic.com" rel="preload"/><script src="https://adservice.google.com/adsid/integrator.js?domain=www.allmusic.com" type="text/javascript"></script><script async="" src="https://securepubads.g.doubleclick.net/gpt/pubads_impl_2020032302.js"></script><link href="//toolbar.complex.com/css/ctoolbar.desktop.min.css" rel="stylesheet" type="text/css"/><style>.inview-level-0.tynt-lazyboy {z-index: 19999!important;}</style><script src="https://s.cpx.to/fire.js?pid=12023&amp;ref=&amp;hn_ver=10&amp;fid=76da222d-e4c3-4fa9-a86a-eabdb4e84411"></script><link href="https://cdn-sic.33across.com/1/stylesheets/sic.css" rel="stylesheet" type="text/css"/><script async="" src="https://sic.33across.com/authorize?gdprConsentLength=0&amp;version=2.62.0&amp;agent=Mozilla%2F5.0%20(Macintosh%3B%20Intel%20Mac%20OS%20X%2010.15%3B%20rv%3A74.0)%20Gecko%2F20100101%20Firefox%2F74.0&amp;product=inview&amp;userId=&amp;sessionId=&amp;publisherURL=https%3A%2F%2Fwww.allmusic.com%2Fmood%2Facerbic-xa0000000931&amp;referrerURL=&amp;publisherId=dXE5DyVPKr6yb7aKlId8sQ&amp;publisher=allmusic.com_impact&amp;viewportWidth=1265&amp;viewportHeight=803&amp;screenWidth=1680&amp;screenHeight=1050&amp;scrollX=0&amp;scrollY=0&amp;pageVisibility=visible&amp;pageWidth=1265&amp;pageHeight=3587&amp;_=1585435006846&amp;callback=_tynt_jp.ajuejj1a9" type="text/javascript"></script></head>
# <body><iframe frameborder="0" id="tynt-ox-iframe-3" style="position: absolute; visibility: hidden; width: 1px; height: 1px;"></iframe><iframe frameborder="0" id="tynt-ox-iframe-2" style="position: absolute; visibility: hidden; width: 1px; height: 1px;"></iframe><iframe frameborder="0" id="tynt-ox-iframe-1" style="position: absolute; visibility: hidden; width: 1px; height: 1px;"></iframe><iframe frameborder="0" id="tynt-apn-ast-container" style="position: absolute; visibility: hidden; width: 1px; height: 1px;"></iframe><div class="tynt-viewability"></div>
# <div class="tynt-ad-fence tynt-ad-fence-startpos-left" style="display:inline-block; position:absolute; margin:-10px; left:0; top:0" tynt-data="no-content">
# <div class="tynt-ad-container" hs-name="lazyboy-rising-star" id="tynt-ad-bb4mbs69" style="display:inline-block; padding:10px">
# <div class="inview-level-0 tynt-lazyboy">
# <div class="inview-level-1" style="transform: translateY(-100%); padding-bottom: 55px;">
# <div class="tynt-close-btn-container">
# <div class="tynt-close-btn" hs-name="Close Button">
#          × Close Ad
#       </div>
# </div> <div class="tynt-ad-frame-container" style="width: 728px; height: 90px;"><iframe class="tynt-ad-frame" frameborder="0" scrolling="no" style="width: 728px; height: 90px;"></iframe></div>
# </div>
# </div>
# </div>
# </div><iframe frameborder="0" id="tynt-gpt-iframe-1" style="position: absolute; visibility: hidden; width: 1px; height: 1px;"></iframe>
# <noscript>
# <div class="javascript-disabled" id="no-js">
#         AllMusic relies heavily on JavaScript.<br/>
#         Please enable JavaScript in your browser to use the site fully.
#     </div>
# </noscript>
# <div class="stripe-container header-leaderboard" style="margin-bottom: 0px;">
# <div class="advertising leaderboard">
# <div class="fw_allmusic" id="cmn_ad_tag_head"><div id="complex_leaderboard_header"></div></div> </div>
# </div>
# <div class="overflow-container mood">
# <div class="stripe-container header-main-nav clearfix">
# <div class="max-header">
# <div class="main-nav">
# <div class="logo-container">
# <a class="logo no-snap" href="/">
# <h3 class="logo-img">AllMusic</h3>
# </a>
# </div>
# <nav class="mobile-menu"></nav>
# <div class="search-container">
# <form action="/search" class="site-search" method="post" name="site-search">
# <input autocomplete="off" class="site-search-input" name="term" placeholder="Search" tabindex="1" type="search"/><div class="allmusic-typeahead" style="display: none; position: absolute;"><div class="typeahead-results searching"><span class="typeahead-searching-msg" style=""><h3 style="color:#A9A9A9;">Searching<span class="dots"></span></h3></span></div><div class="see-all"></div></div>
# <input class="site-search-button" name="submit" type="submit" value=""/>
# </form>
# </div>
# <nav class="site-nav">
# <ul>
# <li class="new-releases">
# <a href="/newreleases">New Releases</a>
# <ul class="new-releases-nav">
# <div class="sub-nav-container">
# <div class="sub-nav-columns">
# <div class="new-releases-subnav left">
# <li class="nr-featured">
# <a href="/newreleases">Featured New Releases</a>
# </li>
# <li class="nr-editorschoice">
# <a href="/newreleases/editorschoice">Editors' Choice</a>
# </li>
# <li class="nr-all">
# <a href="/newreleases/all">All New Releases</a>
# </li>
# </div>
# <div class="new-releases-subnav right">
# <div class="sub-nav-content">
# </div>
# </div>
# </div>
# </div>
# </ul> </li>
# <li class="discover">
# <a href="/discover">Discover</a>
# <ul class="discover-nav">
# <div class="sub-nav-container">
# <div class="sub-nav-columns left">
# <li class="discover-drop-trigger active" id="discover-genres">
# <a href="/genres">Genres<span class="genres-arrow" style="display:none">  ›</span></a>
# </li>
# <li class="discover-drop-trigger" id="discover-moods">
# <a href="/moods">Moods<span class="moods-arrow" style="display:none">  ›</span></a>
# </li>
# <li class="discover-drop-trigger" id="discover-themes">
# <a href="/themes">Themes<span class="themes-arrow" style="display:none">  ›</span></a>
# </li>
# </div>
# <div class="sub-nav-columns right">
# <ul class="discover-genre-secondary">
# <div class="genre-column">
# <!-- spacer to prevent hover weirdness -->
# </div>
# <div class="genre-column">
# <li class="individual">
# <a href="/genre/blues-ma0000002467">Blues</a>
# </li>
# <li class="individual">
# <a href="/genre/classical-ma0000002521">Classical</a>
# </li>
# <li class="individual">
# <a href="/genre/country-ma0000002532">Country</a>
# </li>
# </div>
# <div class="genre-column">
# <li class="individual">
# <a href="/genre/electronic-ma0000002572">Electronic</a>
# </li>
# <li class="individual">
# <a href="/genre/folk-ma0000002592">Folk</a>
# </li>
# <li class="individual">
# <a href="/genre/international-ma0000002660">International</a>
# </li>
# </div>
# <div class="genre-column">
# <li class="individual">
# <a href="/genre/jazz-ma0000002674">Jazz</a>
# </li>
# <li class="individual">
# <a href="/genre/latin-ma0000002692">Latin</a>
# </li>
# <li class="individual">
# <a href="/genre/new-age-ma0000002745">New Age</a>
# </li>
# </div>
# <div class="genre-column">
# <li class="individual">
# <a href="/genre/pop-rock-ma0000002613">Pop/Rock</a>
# </li>
# <li class="individual">
# <a href="/genre/rap-ma0000002816">Rap</a>
# </li>
# <li class="individual">
# <a href="/genre/r-b-ma0000002809">R&amp;B</a>
# </li>
# </div>
# <div class="genre-column">
# <li class="individual">
# <a href="/genre/reggae-ma0000002820">Reggae</a>
# </li>
# <li class="individual">
# <a href="/genre/stage-screen-ma0000004432">Stage &amp; Screen</a>
# </li>
# <li class="last">
# <a href="/genres">All Genres</a>
# </li>
# </div>
# </ul> <ul class="discover-mood-secondary" style="display:none;">
# <div class="mood-column">
# <!-- spacer to prevent hover weirdness -->
# </div>
# <div class="mood-column">
# <li class="individual">
# <a href="/mood
# <a href="/videos">Videos</a>
# </li>
# <li class="blog-all">
# <a href="/blog">All Posts</a>
# </li>
# </div>
# <div class="blog-subnav right">
# <div class="sub-nav-blog-content"></div>
# </div>
# </div>
# </div>
# </ul>
# </li>
# <!--            <li class="videos">-->
# <!--                <a href="/videos" class="videos-link">Video</a>-->
# <!--            </li>-->
# <li class="recommendations">
# <a href="/recommendations">Recommendations</a>
# </li>
# <li class="my-profile">
# <a class="my-profile-link" href="javascript:void(0)">My Profile</a>
# </li>
# <li class="advanced-search">
# <a class="advanced-search-link" href="/advanced-search">Advanced Search</a>
# </li>
# </ul>
# </nav>
# <div class="user-social-nav">
# <nav class="social-nav">
# <ul>
# <li class="facebook">
# <a alt="Like us on Facebook" href="https://www.facebook.com/AllMusicDotCom" title="Like us on Facebook">Facebook</a>
# </li>
# <li class="twitter">
# <a alt="Follow us on Twitter" href="https://twitter.com/#!/Allmusic" title="Follow us on Twitter">Twitter</a>
# </li>
# <li class="tumblr">
# <a alt="Follow us on Tumblr" href="https://allmusic.tumblr.com" title="Follow us on Tumblr">Tumblr</a>
# </li>
# <li class="rss">
# <a alt="Subscribe to our RSS feed" href="/rss" target="_blank" title="Subscribe to our RSS feed">RSS</a>
# </li>
# </ul>
# </nav>
# <nav class="user-notifications">
# <ul>
# <li class="user-notification-icon">
# </li>
# </ul>
# </nav>
# <nav class="user-nav"> <ul class="user-nav-not-logged-in">
# <li class="user-sign-up">
# <a href="/join">Sign Up</a>
# </li>
# <li class="user-nav-divider-line">|</li>
# <li class="user-log-in">
# <a class="open-login-modal" href="#">Log in</a>
# </li>
# </ul>
# </nav>
# </div>
# </div> </div>
# </div>
# <div id="cmn_wrap">
# <div class="content-container">
# <div class="sidebar">
# <div class="advertising medium-rectangle medium-rectangle-atf">
# <div class="complex_square" id="complex_square_atf"></div> </div>
# <section class="recent-releases module">
# <h3 class="headline">
#             Recent Acerbic Releases
#         </h3>
# <ul>
# <li>
# <a class="album-cover" data-hasqtip="0" data-tooltip='{"id":"MW0003330334"}' href="/album/mind-hive-mw0003330334" oldtitle="Wire - Mind Hive" title="">
# <div class="cropped-image crop-image-borders" style="width:109px;height:109px;"><img alt="Mind Hive" class="lazy" data-original="https://cps-static.rovicorp.com/3/JPG_170/MI0004/762/MI0004762677.jpg?partner=allrovi.com" height="110" src="https://cps-static.rovicorp.com/3/JPG_170/MI0004/762/MI0004762677.jpg?partner=allrovi.com" style="display: inline;" width="110"/><noscript><img alt="Mind Hive" height="110" src="https://cps-static.rovicorp.com/3/JPG_170/MI0004/762/MI0004762677.jpg?partner=allrovi.com" style="" width="110"/></noscript></div> </a>
# <div class="artist">
# <a href="https://www.allmusic.com/artist/wire-mn0000672910">Wire</a> </div>
# <div class="title">
# <a data-hasqtip="1" data-tooltip='{"id":"MW0003330334"}' href="https://www.allmusic.com/album/mind-hive-mw0003330334">Mind Hive</a> </div>
# <div class="rating allmusic">
#                         AllMusic <span class="allmusic-rating rating-allmusic-8"></span>
# </div>
# <div class="rating average">
#                         Avg User <span class="average-user-rating rating-average-9" data-id="MW0003330334"></span>
# </div>
# <div class="headline-review">
#                                                     On their compact yet complex 17th album, the legendary post-punkers reinvent their enduring strengths as they lament humanity's vicious, and violent, circles.
#                                                     <div class="author">
#                                 - Heather Phares                            </div>
# </div>
# </li>
# <li>
# <a class="album-cover" data-hasqtip="2" data-tooltip='{"id":"MW0003336987"}' href="/album/hotspot-mw0003336987" oldtitle="Pet Shop Boys - Hotspot" title="">
# <div class="cropped-image crop-image-borders" style="width:109px;height:109px;"><img alt="Hotspot" class="lazy" data-original="https://cps-static.rovicorp.com/3/JPG_170/MI0004/771/MI0004771024.jpg?partner=allrovi.com" height="110" src="https://cps-static.rovicorp.com/3/JPG_170/MI0004/771/MI0004771024.jpg?partner=allrovi.com" style="display: inline;" width="110"/><noscript><img alt="Hotspot" height="110" src="https://cps-static.rovicorp.com/3/JPG_170/MI0004/771/MI0004771024.jpg?partner=allrovi.com" style="" width="110"/></noscript></div> </a>
# <div class="artist">
# <a href="https://www.allmusic.com/artist
title="">
# <div class="cropped-image crop-image-borders" style="width:109px;height:109px;"><img alt="Watchmen, Vol. 3" class="lazy" data-original="https://cps-static.rovicorp.com/3/JPG_170/MI0004/751/MI0004751372.jpg?partner=allrovi.com" height="110" src="//cdn-gce.allmusic.com/images/lazy.gif" style="display: inline;" width="110"/><noscript><img alt="Watchmen, Vol. 3" height="110" src="https://cps-static.rovicorp.com/3/JPG_170/MI0004/751/MI0004751372.jpg?partner=allrovi.com" style="" width="110"/></noscript></div> </a>
# <div class="artist">
# <a href="https://www.allmusic.com/artist/trent-reznor-mn0000017580">Trent Reznor</a> / <a href="https://www.allmusic.com/artist/atticus-ross-mn0000049986">Atticus Ross</a> / <a href="https://www.allmusic.com/artist/trent-reznor-atticus-ross-mn0003888509">Trent  …</a> </div>
# <div class="title">
# <a data-hasqtip="13" data-tooltip='{"id":"MW0003329620"}' href="https://www.allmusic.com/album/watchmen-vol-3-mw0003329620">Watchmen, Vol. 3</a> </div>
# <div class="rating allmusic">
#                         AllMusic <span class="allmusic-rating rating-allmusic-6"></span>
# </div>
# <div class="rating average">
#                         Avg User <span class="average-user-rating rating-average-8" data-id="MW0003329620"></span>
# </div>
# <div class="headline-review">
#                                                     The final installment of the ominous, synth-based soundtrack to the dark superhero television series.
#                                                     <div class="author">
#                                 - Neil Z. Yeung                            </div>
# </div>
# </li>
# <li>
# <a class="album-cover" data-hasqtip="14" data-tooltip='{"id":"MW0003336450"}' href="/album/silhouettes-mw0003336450" oldtitle="Shadow Show - Silhouettes" title="">
# <div class="cropped-image crop-image-borders" style="width:109px;height:109px;"><img alt="Silhouettes" class="lazy" data-original="https://cps-static.rovicorp.com/3/JPG_170/MI0004/766/MI0004766450.jpg?partner=allrovi.com" height="110" src="//cdn-gce.allmusic.com/images/lazy.gif" style="display: inline;" width="110"/><noscript><img alt="Silhouettes" height="110" src="https://cps-static.rovicorp.com/3/JPG_170/MI0004/766/MI0004766450.jpg?partner=allrovi.com" style="" width="110"/></noscript></div> </a>
# <div class="artist">
# <a href="https://www.allmusic.com/artist/shadow-show-mn0003890140">Shadow Show</a> </div>
# <div class="title">
# <a data-hasqtip="15" data-tooltip='{"id":"MW0003336450"}' href="https://www.allmusic.com/album/silhouettes-mw0003336450">Silhouettes</a> </div>
# <div class="rating allmusic">
#                         AllMusic <span class="allmusic-rating rating-allmusic-6"></span>
# </div>
# <div class="rating average">
#                         Avg User <span class="average-user-rating rating-average-8" data-id="MW0003336450"></span>
# </div>
# <div class="headline-review">
#                                                     Debut album from this Detroit trio takes familiar garage and mod pop elements to unexpected places.
#                                                     <div class="author">
#                                 - Fred Thomas                            </div>
# </div>
# </li>
# <li>
# <a class="album-cover" data-hasqtip="16" data-tooltip='{"id":"MW0003341761"}' href="/album/the-private-memoirs-and-confessions-of-the-just-joans-mw0003341761" oldtitle="The Just Joans - The Private Memoirs and Confessions of the Just Joans" title="">
# <div class="cropped-image crop-image-borders" style="width:109px;height:109px;"><img alt="The Private Memoirs and Confessions of the Just Joans" class="lazy" data-original="https://cps-static.rovicorp.com/3/JPG_170/MI0004/764/MI0004764413.jpg?partner=allrovi.com" height="110" src="//cdn-gce.allmusic.com/images/lazy.gif" style="display: inline;" width="110"/><noscript><img alt="The Private Memoirs and Confessions of the Just Joans" height="110" src="https://cps-static.rovicorp.com/3/JPG_170/MI0004/764/MI0004764413.jpg?partner=allrovi.com" style="" width="110"/></noscript></div> </a>
# <div class="artist">
# <a href="https://www.allmusic.com/artist/the-just-joans-mn0001590114">The Just Joans</a> </div>
# <div class="title">
# <a data-hasqtip="17" data-tooltip='{"id":"MW0003341761"}' href="https://www.allmusic.com/album/the-private-memoirs-and-confessions-of-the-just-joans-mw0003341761">The Private Memoirs and Confessions  …</a> </div>
# <div class="rating allmusic">
#                         AllMusic <span class="allmusic-rating rating-allmusic-7"></span>
# </div>
# <div class="rating average">
# ...
# <li class="mog">
# </li>
# </ul>
# </td>
# </tr>
# </tbody></table>
# <h4>
# <a class="note" href="/mood/acerbic-xa0000000931/songs">
#                 More Acerbic Songs
#             </a>
# </h4>
# </section>
# <section class="related">
# <h2 class="headline">Moods Similar to Acerbic</h2>
# <ul>
# <li>
# <a href="https://www.allmusic.com/mood/witty-xa0000001143">Witty</a> </li>
# <li>
# <a href="https://www.allmusic.com/mood/snide-xa0000000767">Snide</a> </li>
# <li>
# <a href="https://www.allmusic.com/mood/literate-xa0000001036">Literate</a> </li>
# </ul>
# <ul>
# <li>
# <a href="https://www.allmusic.com/mood/irreverent-xa0000001028">Irreverent</a> </li>
# <li>
# <a href="https://www.allmusic.com/mood/ironic-xa0000000723">Ironic</a> </li>
# <li>
# <a href="https://www.allmusic.com/mood/humorous-xa0000000717">Humorous</a> </li>
# </ul>
# <ul>
# <li>
# <a href="https://www.allmusic.com/mood/cynical-sarcastic-xa0000000969">Cynical/Sarcastic</a> </li>
# <li>
# <a href="https://www.allmusic.com/mood/cerebral-xa0000000959">Cerebral</a> </li>
# </ul>
# <ul>
# <li>
# <a href="https://www.allmusic.com/mood/bitter-xa0000000945">Bitter</a> </li>
# </ul>
# </section>
# </div>
# </div>
# <div class="stripe-container footer-leaderboard">
# <div class="advertising leaderboard">
# <div class="complex_leaderboard" id="complex_leaderboard_footer"> </div> </div>
# </div>
# <div class="stripe-container footer-container">
# <div class="inner-footer-container">
# <footer>
# <div class="other-sites">
# <a href="//www.allmusic.com/" title="AllMusic - Albums and Artist Database - Music Search, Guide, Recommendations, Videos and Reviews">AllMusic</a>  |
#                     <a href="https://www.allmovie.com/" title="AllMovie - Movies and Films Database - Movie Search, Guide, Recommendations, and Reviews">AllMovie</a>  |
#                     <a href="https://www.sidereel.com/" title="SideReel - Watch TV &amp; Movies Online | Episodes, Seasons, Series | SideReel">SideReel</a>  |
#                     <a href="https://www.celebified.com/" title="Celebified - Celebrity news, watch videos, get tv info">Celebified</a>
# </div>
# <div class="corporate-links">
# <a href="/about" title="AllMusic About">About</a>  |
#                     <a href="/faq" title="AllMusic FAQ">FAQ</a>  |
#                     <a class="getSatisfactionLink" href="https://getsatisfaction.com/allmedianetwork/categories/allmedianetwork_allmusic" title="AllMusic Customer Community">Feedback</a><span class="line-one">  | </span>
# <a href="/advertise" title="AllMusic Advertising Network"><br class="mobile-break"/>Advertise</a>  |
#                     <a href="/copyright-policy" title="AllMusic - Copyright Policy &amp; Intellectual Property Rights">Copyright Policy</a>  |
#                     <a href="/privacy-notice" title="Privacy Notice">Privacy Notice</a>  |
#                     <a href="/terms-of-service" title="AllMusic Terms of Service">Terms of Service</a>  |
#                     <a href="/weekly-new-releases-email" title="New Releases Newsletter">New Releases Newsletter</a>  |
#                     <a href="/subscribe" title="Subscribe">Remove Ads</a>
# </div>
# <div class="copyright">
#                     ©2020 AllMusic, Netaktion LLC<span class="line-two">  |  </span><br class="mobile-break"/>All Rights Reserved
#             </div>
# </footer>
# <div class="ad-padding"></div>
# </div>
# </div>
# <div class="advertisement-div-footer">
# <div data-google-query-id="COiL4NKdvugCFZDHwAodAtYNJw" id="Allmusic_ROS_1x1_Footer"> <div id="google_ads_iframe_/22732481/Allmusic_ROS_1x1_Footer_0__container__" style="border: 0pt none;"><iframe data-google-container-id="2" data-load-complete="true" frameborder="0" height="1" id="google_ads_iframe_/22732481/Allmusic_ROS_1x1_Footer_0" marginheight="0" marginwidth="0" name="google_ads_iframe_/22732481/Allmusic_ROS_1x1_Footer_0" scrolling="no" style="border: 0px none; vertical-align: bottom;" title="3rd party ad content" width="1"></iframe></div></div> </div>
# <script src="//cdn-gce.allmusic.com/cache/dist/js/global-08b8485d32.js"></script>
# <script src="//cdn-gce.allmusic.com/cache/dist/js/mood-f982d690bc.overview.js"></script>
# <script>
#         if(User.loggedIn) {
#             ga('set', 'dimension1', 'Yes');
#                         ga('set', 'dimension3', 'No');
#                     } else {
#             ga('set', 'dimension1', 'No');
#         }
#     </script>
# <!-- BEGIN GetSat -->
# <script charset="utf-8" type="text/javascript">
#     var is_ssl = ("https:" == document.location.protocol);
#     var asset_host = is_ssl ? "https://d11e618678w89x.cloudfront.net/" : "http://d11e618678w89x.cloudfront.net/";
#     document.write(unescape("%3Cscript src='" + asset_host + "javascripts/feedback-v2.js' type='text/javascript'%3E%3C/script%3E"));
# </script><script src="https://d11e618678w89x.cloudfront.net/javascripts/feedback-v2.js" type="text/javascript"></script>
# <script charset="utf-8" type="text/javascript">
#     var feedback_widget = new GSFN.feedback_widget({
#         display: 'overlay',
#         company: 'allmedianetwork',
#         placement: 'hidden',
#         custom_css: '//cdn-gce.allmusic.com/css/modules/feedback-widget.css',
#         color: '#222',
#         style: 'idea',
#         limit: '3',
#         product: 'allmedianetwork_allmusic'
#     });
# </script><a class="fdbk_tab_hidden" href="#" id="fdbk_tab" style="background-color:#222">FEEDBACK</a><div id="fdbk_overlay" style="display:none"><div id="fdbk_container"><a href="#" id="fdbk_close"></a><iframe allowtransparency="true" class="loading" frameborder="0" height="100%" id="fdbk_iframe" scrolling="no" style="width: 658px; height: 100%;" width="658px"></iframe></div><div id="fdbk_screen"></div></div>
# <!-- END GetSat -->
# <!-- Begin comScore Tag -->
# <script>
#     var _comscore = _comscore || [];
#     _comscore.push({ c1: "2", c2: "6685975" });
#     (function() {
#         var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
#         s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
#         el.parentNode.insertBefore(s, el);
#     })();
# </script>
# <noscript>
# <img src="//b.scorecardresearch.com/p?c1=2&amp;c2=6685975&amp;cv=2.0&amp;cj=1"/>
# </noscript>
# <!-- End comScore Tag -->
# </div>
# </div><iframe name="__cmpLocator" style="display: none;"></iframe>
# <!-- Footer Ad Tag -->
# <script type="text/javascript">
# (function() {
# window.cToolbarInit = function() {
# cToolbar.load({
# mobileRightButton: 'email',
# facebookUsername: 'AllMusicDotCom',
# facebookName: 'AllMusic',
# twitterHandle: 'allmusic',
# twitterName: 'allmusic',
# youtubeChannel: '',
# youtubeChannelName: '',
# desktopBackground: 'solid',
# desktopSocialButtons: ["twitter","facebook"],
# channel: 'Music'
# });
# };
# var ns = document.createElement('script');
# ns.type = 'text/javascript';
# ns.async = true;
# ns.src = '//toolbar.complex.com/dist/ctoolbar.min.js';
# var s = document.getElementsByTagName('script')[0];
# s.parentNode.insertBefore(ns, s);
# })();
# </script><script type="text/javascript">
#     _qevents.push({
#         qacct:"p-59TntzuqummDw",
#         labels:"AllMedia.AllMusic"
#     });
# </script>
# <noscript>
# <div style="display:none;">
# <img alt="Quantcast" border="0" height="1" src="//pixel.quantserve.com/pixel/p-59TntzuqummDw.gif?labels=AllMedia" width="1"/>
# </div>
# </noscript>
# <!-- Double Verify -->
# <img alt="" height="0" src="https://tps30.doubleverify.com/visit.jpg?ctx=2908533&amp;cmp=2736444&amp;sid=24324&amp;plc=DV-RTHM20170324001&amp;advid=2908534&amp;region=30&amp;btadsrv=rhythmone&amp;app=appid&amp;sup=sspid&amp;DVP_DV_TT=2&amp;DVP_DV_CT=1&amp;DVP_APPID=NotApplicable&amp;DVP_SSPID=NotApplicable&amp;DVP_PUBID=NotApplicable&amp;DVP_PP_BUNDLE_ID=NotApplicable&amp;DVP_RO_SSPID=NotApplicable&amp;DVP_PP_ORTB_PUB_ID=NotApplicable&amp;DVP_RO_SITEID=NotApplicable&amp;DVP_RO_TRAFFIC=NotApplicable&amp;DVP_PP_DEAL_ID=NotApplicable&amp;DVPX_PP_IMP_ID=NotApplicable&amp;DVPX_PP_UID=NotApplicable&amp;DVP_RO_CDID=NotApplicable&amp;DVPX_PP_AUCTION_UA=Mozilla%2F5.0+%28Macintosh%3B+Intel+Mac+OS+X+10.15%3B+rv%3A74.0%29+Gecko%2F20100101+Firefox%2F74.0&amp;DVP_PP_AUCTION_IP=10.128.2.74&amp;turl=AllMusic.com&amp;dvtagver=6.1.img" width="0"/>
# <!-- End Double Verify -->
# <!-- captify pixel -->
# <script>
#                 (function(c,a,p,t,i,f,y){i=c.createElement(a);t=c.getElementsByTagName(a)[0];i.type='text/javascript';i.async=true;i.src=p;t.parentNode.insertBefore(i,t);})(document,'script','//p.cpx.to/p/12023/px.js');
#     </script>
# <script type="text/javascript">
# (function(){
# var initialLoadAds = function(isMobile){
# if(!isMobile){
# CMNUNT.load('3x3', {
# containerId: 'complex_leaderboard_header'
# });
# CMNUNT.load('300x250,300x600', {
# containerId: 'complex_square_atf'
# });
# CMNUNT.load('300x250,300x600', {
# containerId: 'complex_square_btf'
# ,lazyLoad: true
# });
# CMNUNT.load('728x91', {
# containerId: 'complex_leaderboard_footer'
# ,lazyLoad: true
# });
# } else {
# CMNUNT.load('top', {
# containerId: 'complex_leaderboard_header'
# });
# CMNUNT.load('content', {
# containerId: 'complex_square_atf'
# ,lazyLoad: true
# });
# }
# return true;
# };
# var firstAdsLoaded = false;
# if(document.readyState === 'complete' && !firstAdsLoaded){
# firstAdsLoaded = initialLoadAds(isMobile);
# } else {
# document.addEventListener('readystatechange', function(){
# if(document.readyState === 'complete' && !firstAdsLoaded){
# firstAdsLoaded = initialLoadAds(isMobile);
# }
# });
# }
# })();
# </script>
# <script>
#         $.getScript("/ads.js", function (data, textStatus, jqxhr) {
#             // success block
#             ga('send', 'event', 'setCustomDimension', 1, {
#                 'dimension2': 'not_adblocking',
#                 'nonInteraction': true
#             });
#
#         })
#         .fail(function () {
#             ga('send', 'event', 'setCustomDimension', 1, {
#                 'dimension2': 'is_adblocking',
#                 'nonInteraction': true
#             });
#
#             // fire ad block detected GA event
#             allmusic.gaTrackEvent({data: ["AdBlock", "Interaction", "User Has Adblock Enabled"]});
#             if (!Cookie.read('adblock_dismiss')) {
#
#                 // fire ad block modal fires GA event
#                 allmusic.gaTrackEvent({data: ["AdBlock", "Interaction", "AdBlock Modal Fires"]});
#
#                 $.ajax({
#                     url: '//' + urlSubdomain + '.allmusic.com/blocker_check',
#                     type: 'GET',
#                     cache: false,
#                     success: function (data) {
#                         // append to body
#                         $(document).find('body').append(data);
#                         // lock body
#                         $(document).find('body').addClass('noscroll');
#                         document.getElementById('cmn-toolbar-wrap').style.zIndex = 20000;
#                     }
#                 });
#
#             } else {
#                 allmusic.gaTrackEvent({data: ["AdBlock", "Interaction", "User Has AdBlock Dismiss Cookie"]});
#             }
#         });
#     </script>
# <script type="text/javascript">window.NREUM||(NREUM={});NREUM.info={"beacon":"bam.nr-data.net","licenseKey":"37e6a77380","applicationID":"39608998","transactionName":"NlMEYhZXW0oEWkQNVg8ZJ1UQX1pXSnRfC10SGQlAAURDUABO","queueTime":0,"applicationTime":3278,"atts":"GhQTFF5NSBVHWBJeQhxL","errorBeacon":"bam.nr-data.net","agent":""}</script>
# <iframe height="0" sandbox="allow-scripts allow-same-origin" src="https://ads.pubmatic.com/AdServer/js/pwtSync/load-cookie.html?pubid=158774&amp;profid=1905&amp;bidders=appnexus,audienceNetwork,consumable,ix,kargo,pubmatic,rubicon,triplelift,yieldmo" style="display: none;" title="User Sync" width="0"></iframe><div class="tb-desktop" id="ctoolbar"> <div class="ctoolbar-desktop tb-dark tb-solid">
# <div class="tb-box tb-logo">
# <a href="https://about.complex.com" id="tb-logo-link" target="_self"><span class="tb-logo-icon"></span></a>
# </div>
# <div class="tb-box tb-category">
# <div class="tb-category-label">Music</div>
# </div>
# <div class="tb-box tb-share">
# <!--
#                 <div class="tb-facebook tb-inactive tb-btn">
#                     <a href="" target="_blank"class="tb-btn-top-panel">
#                         <i class="tb-facebook-icon"></i> <span class="tb-social-btn-label">Like</span> <span id="tb-facebook-like-text"></span>
#                     </a>
#                     <div class="fb-like-container tb-btn-bottom-panel"></div>
#
#                 </div>
#
#                 <div class="tb-twitter tb-inactive tb-btn">
#                     <a href="" target="_blank" class="tb-btn-top-panel">
#                         <i class="tb-twitter-icon"></i> <span class="tb-social-btn-label">Follow</span> <span id="tb-twitter-follow-text"></span></a>
#                     <div class="twitter-follow-container tb-btn-bottom-panel"></div>
#                 </div>
#
#                 <div class="tb-youtube tb-inactive tb-btn">
#                     <a href="" target="_blank" class="tb-btn-top-panel"><i class="tb-youtube-icon"></i> <span class="tb-social-btn-label">Subscribe</span> <span id="tb-youtube-subscribe-text"></span>
#                     </a>
#                     <div class="youtube-sucscribe-container tb-btn-bottom-panel">
#                         <div class="g-ytsubscribe" data-channel="" data-layout="default" data-count="default"></div>
#                     </div>
#                 </div>
#                 -->
# <div class="tb-btn tb-twitter"><a class="tb-btn-url" href="http://twitter.com/allmusic" target="_blank">
# <i class="tb-btn-icon"></i> <span class="tb-btn-label">Follow allmusic</span>
# </a></div><div class="tb-btn tb-facebook"><a class="tb-btn-url" href="http://facebook.com/AllMusicDotCom" target="_blank">
# <i class="tb-btn-icon"></i> <span class="tb-btn-label">Like AllMusic</span>
# </a></div></div>
# <div class="tb-box tb-ad">
# <div class="adUnits footer-ad" data-cmnunt-ad-size="7x7" data-google-query-id="CPGVmNOdvugCFVI_TwodyykIFw" id="cmn_ad_toolbar" style=""><div id="google_ads_iframe_/5202/allmusic/internal_0__container__" style="border: 0pt none;"><iframe data-google-container-id="3" data-load-complete="true" frameborder="0" height="50" id="google_ads_iframe_/5202/allmusic/internal_0" marginheight="0" marginwidth="0" name="google_ads_iframe_/5202/allmusic/internal_0" scrolling="no" style="border: 0px none; vertical-align: bottom;" title="3rd party ad content" width="320"></iframe></div></div>
# </div>
# </div>
# <div class="tb-toggle"><span class="tb-toggle-text">Close</span> <i class="tb-chevron-circle-right"></i></div>
# </div><div id="PGRgDhbHAZXq" style="display: none;"></div><iframe src="https://s.amazon-adsystem.com/iu3?cm3ppd=1&amp;d=dtb-pub&amp;csif=t&amp;dl=gg_ym_rbd_oath_rx_dm_dmx_3lift" style="display: none;"></iframe><iframe id="google_osd_static_frame_5279972318547" name="google_osd_static_frame" style="display: none; width: 0px; height: 0px;"></iframe><iframe referrerpolicy="unsafe-url" src="https://secure-assets.rubiconproject.com/utils/xapi/multi-sync.html?p=33across&amp;endpoint=us-east" style="position: absolute; overflow: hidden; visibility: hidden; height: 1px; width: 1px; bottom: 1px; left: 1px;"></iframe><iframe referrerpolicy="unsafe-url" src="https://ssc-cms.33across.com/ps/?gdpr_58=&amp;gdpr_consent=&amp;ts=1585435007063.5&amp;ri=70&amp;ru=https%3A%2F%2Fus-u.openx.net%2Fw%2F1.0%2Fcm%3Fid%3Dc6a5ba0d-ce02-41bd-a1ea-842c68bd5108%26ph%3D8f5ed5d4-642c-4222-968a-d709c87ac3c8%26gdpr_consent%3D%24%7Bgdpr_consent%7D%26r%3Dhttps%253A%252F%252Fcms-xch-chicago.33across.com%252Fmatch%253Fgdpr%253D%24%7Bgdpr%7D%2526gdpr_58%253D%24gdpr_58%2526gdpr_consent%253D%24%7Bgdpr_consent%7D%2526bidder_id%253D70%2526external_user_id%253D" style="position: absolute; overflow: hidden; visibility: hidden; height: 1px; width: 1px; bottom: 1px; left: 1px;"></iframe><div class="cookie-policy-box" style="display: block; opacity: 0.00290472;"><div class="cookie-policy-inner"><div class="text-wrapper">By using this site, you consent to the use of cookies. <br class="mobile-only"/> For more information, please <a href="/cookies">read our cookie policy.</a><a class="cookie-policy-close" href="#">CLOSE [X]</a></div></div></div></body></html>

# %%
def process_mood(ind):
    driver = webdriver.Firefox(executable_path='/Users/prasannsinghal/Desktop/geckodriver')
    driver.get(urls[ind])

    html = driver.page_source
    soup = BeautifulSoup(html)
    driver.quit()
    try:
        rows = soup.find_all("tbody")[0].find_all("tr")

        print(len(rows))
        data = []
        for row in rows:
            a = {}
            a['title'] = row.find_all("a")[0].text
            a['artist'] = row.find_all("a")[1].text
            data.append(a)
    except:
        data = process_mood(ind+1)
    return data

# %%
process_mood(3)
# Out:
# 10
# [{'title': 'How Can You Mend a Broken Heart?', 'artist': 'Bee Gees'},
#  {'title': 'Lucy in the Sky With Diamonds', 'artist': 'The Beatles'},
#  {'title': "Sgt. Pepper's Lonely Hearts Club Band", 'artist': 'The Beatles'},
#  {'title': 'A Day in the Life', 'artist': 'The Beatles'},
#  {'title': 'Magical Mystery Tour', 'artist': 'The Beatles'},
#  {'title': 'The Fixer', 'artist': 'Pearl Jam'},
#  {'title': 'Violet Hill', 'artist': 'Coldplay'},
#  {'title': 'Viva la Vida', 'artist': 'Coldplay'},
#  {'title': 'Supermassive Black Hole', 'artist': 'Muse'},
#  {'title': 'Starlight', 'artist': 'Muse'}]
